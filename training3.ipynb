# %%
import torch
import torch.nn as nn
import torch.optim as optim
import gymnasium as gym
import numpy as np
import ale_py
import time, os, pickle

# %%
# Hyperparameters
learning_rate = 0.00005
hidden_dim = 128
gamma = 0.995
epsilon = 1.0
epsilon_decay = 0.997
epsilon_min = 0.05

# Reward Parameters
line_clear_reward = 2.0
step_penalty = -0.02
game_over_penalty = -20.0

# Training Episodes
num_episodes = 1000

# %%
gym.register_envs(ale_py)
env = gym.make("ALE/Tetris-v5", render_mode="human")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
state, _ = env.reset()
save_dir = "training_logs2"
os.makedirs(save_dir, exist_ok=True)
print(dir(env))

class Actor(nn.Module):
    def __init__(self, action_dim, hidden_dim=128):
        super(Actor, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5, stride=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1)

        # Use a dummy input to calculate the flattened size after conv layers
        with torch.no_grad():
            dummy_input = torch.zeros(1, 3, state.shape[0], state.shape[1])
            conv_output = self.conv_layers(dummy_input)
            conv_output_size = conv_output.view(-1).size(0)

        # Define fully connected layers
        self.fc1 = nn.Linear(conv_output_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, action_dim)

    def conv_layers(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        x = torch.relu(self.conv3(x))
        return x

    def forward(self, state):
        x = self.conv_layers(state)
        x = x.reshape(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        action_probs = torch.softmax(self.fc2(x), dim=-1)
        return action_probs

class Critic(nn.Module):
    def __init__(self, hidden_dim=128):
        super(Critic, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=4, stride=2)

        with torch.no_grad():
            dummy_input = torch.zeros(1, 3, state.shape[0], state.shape[1])
            conv_output = self.conv_layers(dummy_input)
            conv_output_size = conv_output.view(-1).size(0)

        self.fc1 = nn.Linear(conv_output_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def conv_layers(self, x):
        x = torch.relu(self.conv1(x))
        x = torch.relu(self.conv2(x))
        return x

    def forward(self, state):
        x = self.conv_layers(state)
        x = x.reshape(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        state_value = self.fc2(x)
        return state_value

def calculate_reward(lines_cleared, game_over, state):
    line_clear_reward = 1.0
    game_over_penalty = -10.0
    step_penalty = -0.01
    tower_height_penalty = -0.1  
    gaps_penalty = -0.05         

    reward = line_clear_reward * lines_cleared if lines_cleared > 0 else step_penalty

    if game_over:
        reward += game_over_penalty

    if state.shape[-1] == 3: 
        state = state.mean(axis=-1)  

    column_heights = []
    for col in range(state.shape[1]):
        column = state[:, col]
        non_zero_indices = np.where(column > 0)[0]  
        if len(non_zero_indices) > 0:
            column_heights.append(len(state) - non_zero_indices[0]) 
        else:
            column_heights.append(0)  

    tallest_column = max(column_heights)
    reward += tower_height_penalty * tallest_column

    num_gaps = 0
    for col in range(state.shape[1]):
        column = state[:, col]
        non_zero_indices = np.where(column > 0)[0]
        if len(non_zero_indices) > 0:
            highest_filled_row = non_zero_indices[0]
            gaps_below = np.sum(column[highest_filled_row + 1:] == 0)
            num_gaps += gaps_below

    reward += gaps_penalty * num_gaps

    return reward


def train_step(state, action, reward, next_state, done):
    state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).permute(0, 3, 1, 2) / 255.0
    next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).permute(0, 3, 1, 2) / 255.0
    action = torch.tensor(action, dtype=torch.long)
    reward = torch.tensor(reward, dtype=torch.float32)

    # Critic update with gradient clipping
    value = critic(state)
    next_value = critic(next_state) * (1 - done)
    target_value = reward + gamma * next_value
    critic_loss = (value - target_value.detach()) ** 2

    critic_optimizer.zero_grad()
    critic_loss.backward()
    torch.nn.utils.clip_grad_norm_(critic.parameters(), max_norm=1.0)
    critic_optimizer.step()

    # Actor update with gradient clipping
    advantage = (target_value - value).detach()
    action_probs = actor(state)
    log_prob = torch.log(action_probs.squeeze(0)[action])
    actor_loss = -log_prob * advantage

    actor_optimizer.zero_grad()
    actor_loss.backward()
    torch.nn.utils.clip_grad_norm_(actor.parameters(), max_norm=1.0)
    actor_optimizer.step()

    return actor_loss.item(), critic_loss.item()

# Actor and Critic networks and optimizers
actor = Actor(action_dim=env.action_space.n)
critic = Critic()
actor_optimizer = optim.Adam(actor.parameters(), lr=learning_rate)
critic_optimizer = optim.Adam(critic.parameters(), lr=learning_rate)
print(action_dim)

# parameters and metrics
def save_parameters_and_metrics(episode, actor, critic, actor_optimizer, critic_optimizer, metrics):
    torch.save({
        'actor_state_dict': actor.state_dict(),
        'critic_state_dict': critic.state_dict(),
        'actor_optimizer_state_dict': actor_optimizer.state_dict(),
        'critic_optimizer_state_dict': critic_optimizer.state_dict()
    }, os.path.join(save_dir, f"model_checkpoint_ep{episode}.pt"))

    with open(os.path.join(save_dir, "training_metrics.pkl"), "wb") as f:
        pickle.dump(metrics, f)

metrics = {
    "episode_rewards": [],
    "step_actor_losses": [],
    "step_critic_losses": []
}

# Define a function to print the average weights and losses
def print_parameters_and_losses(actor, critic, episode, avg_actor_loss, avg_critic_loss):
    print(f"\n--- Statistics at Episode {episode} ---")
    
    # Print the average weight of specific layers
    actor_conv1_avg = actor.conv1.weight.data.mean().item()
    print(f"Actor Layer 1 Conv Weights Average: {actor_conv1_avg}")
    
    actor_fc1_avg = actor.fc1.weight.data.mean().item()
    print(f"Actor Layer 1 FC Weights Average: {actor_fc1_avg}")
    
    critic_conv1_avg = critic.conv1.weight.data.mean().item()
    print(f"Critic Layer 1 Conv Weights Average: {critic_conv1_avg}")
    
    critic_fc1_avg = critic.fc1.weight.data.mean().item()
    print(f"Critic Layer 1 FC Weights Average: {critic_fc1_avg}")

    # Print average losses for actor and critic
    print(f"Average Actor Loss: {avg_actor_loss}")
    print(f"Average Critic Loss: {avg_critic_loss}")
    
    print("--- End of Statistics ---\n")

for episode in range(num_episodes):
    state, _ = env.reset()
    done = False
    episode_reward = 0
    actor_losses = []
    critic_losses = []

    while not done:
        # Preprocess state for model input
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).permute(0, 3, 1, 2) / 255.0

        # Get action probabilities from the actor network
        action_probs = actor(state_tensor).detach().numpy().squeeze()

        # ε-greedy action selection
        if np.random.rand() < epsilon:
            # Exploration: choose a random action
            action = np.random.choice(action_dim)
        else:
            # Exploitation: choose the action with the highest probability
            action = np.argmax(action_probs)

        # Decay epsilon after each step
        epsilon = max(epsilon * epsilon_decay, epsilon_min)

        # Take the action in the environment
        next_state, _, done, _, info = env.step(action)
        
        # Calculate reward
        lines_cleared = info.get("lines_cleared", 0)
        reward = calculate_reward(lines_cleared, done, state)
        episode_reward += reward

        # Train actor and critic networks
        actor_loss, critic_loss = train_step(state, action, reward, next_state, done)

        # Log losses for each step
        actor_losses.append(actor_loss)
        critic_losses.append(critic_loss)

        # Update the state
        state = next_state

    # Calculate average losses for this episode
    avg_actor_loss = np.mean(actor_losses)
    avg_critic_loss = np.mean(critic_losses)

    # Print the episode results with average losses
    print(f"Episode {episode + 1}: Total Reward = {episode_reward}, Avg Actor Loss = {avg_actor_loss:.4f}, Avg Critic Loss = {avg_critic_loss:.4f}")

env.close()
# Out:
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_action_space', '_cached_spec', '_disable_render_order_enforcing', '_has_reset', '_is_protocol', '_metadata', '_np_random', '_np_random_seed', '_observation_space', '_saved_kwargs', 'action_space', 'class_name', 'close', 'env', 'get_wrapper_attr', 'has_reset', 'has_wrapper_attr', 'metadata', 'np_random', 'np_random_seed', 'observation_space', 'render', 'render_mode', 'reset', 'set_wrapper_attr', 'spec', 'step', 'unwrapped', 'wrapper_spec']
# 5
# Episode 1: Total Reward = -635977.089999998, Avg Actor Loss = -1815.7746, Avg Critic Loss = 1346766.6523
# Episode 2: Total Reward = -619759.3499999975, Avg Actor Loss = -1631.5687, Avg Critic Loss = 3513192.9299
# Episode 3: Total Reward = -524769.7299999949, Avg Actor Loss = -914.3970, Avg Critic Loss = 31544139.5647
# Episode 4: Total Reward = -603541.6099999971, Avg Actor Loss = 186.0854, Avg Critic Loss = 101842483.8601
# Episode 5: Total Reward = -691580.7699999996, Avg Actor Loss = 509.5471, Avg Critic Loss = 93998540.3840
# Episode 6: Total Reward = -589640.6899999967, Avg Actor Loss = 656.0331, Avg Critic Loss = 110299956.7004
# Episode 7: Total Reward = -552571.5699999956, Avg Actor Loss = 651.0135, Avg Critic Loss = 115530005.4238
# Episode 8: Total Reward = -534037.0099999951, Avg Actor Loss = 121.0851, Avg Critic Loss = 116183901.2862
# Episode 9: Total Reward = -529403.369999995, Avg Actor Loss = 85.6655, Avg Critic Loss = 116270117.3028
# Episode 10: Total Reward = -499284.7099999954, Avg Actor Loss = 680.6916, Avg Critic Loss = 124388195.5546
# Episode 11: Total Reward = -166821.0400000004, Avg Actor Loss = 586.0341, Avg Critic Loss = 417453907.7090
# Episode 12: Total Reward = -121643.05000000026, Avg Actor Loss = 1010.8257, Avg Critic Loss = 576872543.3299
# Episode 13: Total Reward = -98474.8500000002, Avg Actor Loss = 950.9493, Avg Critic Loss = 674056673.8356
# Episode 14: Total Reward = -104266.90000000021, Avg Actor Loss = 893.3867, Avg Critic Loss = 649574414.8488
# Episode 15: Total Reward = -107742.13000000022, Avg Actor Loss = 1230.1740, Avg Critic Loss = 634828732.5010
# Episode 16: Total Reward = -101950.0800000002, Avg Actor Loss = 2034.9631, Avg Critic Loss = 673219240.6123
# Episode 17: Total Reward = -97316.44000000019, Avg Actor Loss = 2137.9093, Avg Critic Loss = 705114634.3262
# Episode 18: Total Reward = -98474.8500000002, Avg Actor Loss = 1781.7731, Avg Critic Loss = 683535989.8877
# Episode 19: Total Reward = -119326.23000000026, Avg Actor Loss = 1537.6988, Avg Critic Loss = 577161985.1108
# Episode 20: Total Reward = -99633.2600000002, Avg Actor Loss = 2392.8154, Avg Critic Loss = 688059049.8778
# Episode 21: Total Reward = -98474.8500000002, Avg Actor Loss = 2865.0107, Avg Critic Loss = 706280584.4568
# Episode 22: Total Reward = -106583.72000000022, Avg Actor Loss = 3421.6654, Avg Critic Loss = 650910804.7913
# Episode 23: Total Reward = -118167.82000000025, Avg Actor Loss = 2608.3933, Avg Critic Loss = 596927116.7947
# Episode 24: Total Reward = -97316.44000000019, Avg Actor Loss = 3264.8889, Avg Critic Loss = 708605324.2721
# Episode 25: Total Reward = -106583.72000000022, Avg Actor Loss = 3129.2549, Avg Critic Loss = 645151789.0773
# Episode 26: Total Reward = -103108.49000000021, Avg Actor Loss = 3099.5548, Avg Critic Loss = 665586109.3302
# Episode 27: Total Reward = -110058.95000000023, Avg Actor Loss = 2400.9555, Avg Critic Loss = 620935016.7617
# Episode 28: Total Reward = -103108.49000000021, Avg Actor Loss = 2995.0818, Avg Critic Loss = 675779952.4359
# Episode 29: Total Reward = -98474.8500000002, Avg Actor Loss = 2600.6959, Avg Critic Loss = 684897597.2761
# Episode 30: Total Reward = -99633.2600000002, Avg Actor Loss = 3268.5983, Avg Critic Loss = 692295311.6319
# Episode 31: Total Reward = -117009.41000000025, Avg Actor Loss = 2439.1917, Avg Critic Loss = 589532378.1619
# Episode 32: Total Reward = -104266.90000000021, Avg Actor Loss = 3292.3289, Avg Critic Loss = 666189720.5636
# Episode 33: Total Reward = -106583.72000000022, Avg Actor Loss = 2042.4499, Avg Critic Loss = 633600665.7561
# Episode 34: Total Reward = -144811.25000000032, Avg Actor Loss = 1549.6810, Avg Critic Loss = 477681417.2356
# Episode 35: Total Reward = -557205.2099999958, Avg Actor Loss = 534.3340, Avg Critic Loss = 111227918.1295
# Episode 36: Total Reward = -585007.0499999966, Avg Actor Loss = 492.7603, Avg Critic Loss = 105105250.7649
# Episode 37: Total Reward = -501601.5299999954, Avg Actor Loss = 515.7493, Avg Critic Loss = 126241103.6863
# Episode 38: Total Reward = -682313.4899999993, Avg Actor Loss = 401.2600, Avg Critic Loss = 94337233.3847
# Episode 39: Total Reward = -547937.9299999955, Avg Actor Loss = 493.0785, Avg Critic Loss = 113339222.4276
# Episode 40: Total Reward = -821322.6900000032, Avg Actor Loss = -25.7552, Avg Critic Loss = 74790833.1767
# Episode 41: Total Reward = -534037.0099999951, Avg Actor Loss = -24.9445, Avg Critic Loss = 115989596.3598
# Episode 42: Total Reward = -473799.689999996, Avg Actor Loss = -27.3810, Avg Critic Loss = 130815303.8484
# Episode 43: Total Reward = -515502.44999999506, Avg Actor Loss = -8.3102, Avg Critic Loss = 123709578.6004
# Episode 44: Total Reward = -788887.2100000023, Avg Actor Loss = 0.1725, Avg Critic Loss = 80059984.2345
# Episode 45: Total Reward = -529403.369999995, Avg Actor Loss = 4929.4359, Avg Critic Loss = 117608338.5481
# Episode 46: Total Reward = -686947.1299999994, Avg Actor Loss = -14.3362, Avg Critic Loss = 91311232.6312
# Episode 47: Total Reward = -529403.369999995, Avg Actor Loss = -17.9560, Avg Critic Loss = 116763461.6964
# Episode 48: Total Reward = -469166.0499999961, Avg Actor Loss = -16.1164, Avg Critic Loss = 131563099.0035
# Episode 49: Total Reward = -483066.9699999958, Avg Actor Loss = -10.4914, Avg Critic Loss = 128723504.8241
# Episode 50: Total Reward = -529403.369999995, Avg Actor Loss = -13.9143, Avg Critic Loss = 116756279.2364
# Episode 51: Total Reward = -506235.16999999527, Avg Actor Loss = -10.4720, Avg Critic Loss = 122523446.3409
# Episode 52: Total Reward = -492334.2499999956, Avg Actor Loss = -12.0993, Avg Critic Loss = 126608306.5725
# Episode 53: Total Reward = -524769.7299999949, Avg Actor Loss = -11.2284, Avg Critic Loss = 117089799.4814
# Episode 54: Total Reward = -469166.0499999961, Avg Actor Loss = 14.3560, Avg Critic Loss = 133177517.1194
# Episode 55: Total Reward = -464532.4099999962, Avg Actor Loss = -16.9010, Avg Critic Loss = 133616709.0668
# Episode 56: Total Reward = -413562.3699999973, Avg Actor Loss = -48.9581, Avg Critic Loss = 149498755.2952
# Episode 57: Total Reward = -422829.6499999971, Avg Actor Loss = -17.5071, Avg Critic Loss = 147530553.4683
# Episode 58: Total Reward = -617442.5299999975, Avg Actor Loss = -6.8286, Avg Critic Loss = 99169290.5004
# Episode 59: Total Reward = -543304.2899999954, Avg Actor Loss = -13.1099, Avg Critic Loss = 114832649.6990
# Episode 60: Total Reward = -501601.5299999954, Avg Actor Loss = -21.6193, Avg Critic Loss = 123632677.9949
# Episode 61: Total Reward = -677679.8499999992, Avg Actor Loss = 4977.0153, Avg Critic Loss = 90593996.9067
# Episode 62: Total Reward = -552571.5699999956, Avg Actor Loss = -24.3501, Avg Critic Loss = 111570900.3678
# Episode 63: Total Reward = -617442.5299999975, Avg Actor Loss = -28.7726, Avg Critic Loss = 101146584.1701
# Episode 64: Total Reward = -501601.5299999954, Avg Actor Loss = -18.7074, Avg Critic Loss = 124473981.5071
# Episode 65: Total Reward = -422829.6499999971, Avg Actor Loss = -14.3340, Avg Critic Loss = 146607501.9512
# Episode 66: Total Reward = -445997.8499999966, Avg Actor Loss = -19.2789, Avg Critic Loss = 139306298.6693
# Episode 67: Total Reward = -735600.3500000008, Avg Actor Loss = 6000.0192, Avg Critic Loss = 83343047.1906
# Episode 68: Total Reward = -714748.9700000002, Avg Actor Loss = -25.6938, Avg Critic Loss = 86855424.7671
# Episode 69: Total Reward = -178405.14000000042, Avg Actor Loss = 2140.6868, Avg Critic Loss = 392656896.4211
# Episode 70: Total Reward = -113534.18000000024, Avg Actor Loss = 1787.4759, Avg Critic Loss = 587649816.4730
# Episode 71: Total Reward = -575739.7699999963, Avg Actor Loss = -15.9962, Avg Critic Loss = 106263369.3128
# Episode 72: Total Reward = -492334.2499999956, Avg Actor Loss = -80.4380, Avg Critic Loss = 126324754.4522
# Episode 73: Total Reward = -557205.2099999958, Avg Actor Loss = -14.4533, Avg Critic Loss = 111594179.8253
# Episode 74: Total Reward = -450631.4899999965, Avg Actor Loss = -103.4239, Avg Critic Loss = 137888240.8581
# Episode 75: Total Reward = -184197.19000000044, Avg Actor Loss = 484.7870, Avg Critic Loss = 371196323.9389
# Episode 76: Total Reward = -580373.4099999964, Avg Actor Loss = -34.6463, Avg Critic Loss = 107037606.7912
# Episode 77: Total Reward = -668412.5699999989, Avg Actor Loss = -24.5282, Avg Critic Loss = 91566623.4838
# Episode 78: Total Reward = -469166.0499999961, Avg Actor Loss = -18.0579, Avg Critic Loss = 132330602.1720
# Episode 79: Total Reward = -571106.1299999962, Avg Actor Loss = -32.1070, Avg Critic Loss = 110261840.1960
# Episode 80: Total Reward = -608175.2499999972, Avg Actor Loss = 24.9923, Avg Critic Loss = 101003018.3056
# Episode 81: Total Reward = -557205.2099999958, Avg Actor Loss = -32.2505, Avg Critic Loss = 111662059.5739
# Episode 82: Total Reward = -515502.44999999506, Avg Actor Loss = -15.2424, Avg Critic Loss = 120335055.5725
# Episode 83: Total Reward = -473799.689999996, Avg Actor Loss = -25.5775, Avg Critic Loss = 130151451.2374
# Episode 84: Total Reward = -598907.969999997, Avg Actor Loss = -15.3229, Avg Critic Loss = 103508633.4656
# Episode 85: Total Reward = -557205.2099999958, Avg Actor Loss = -18.8856, Avg Critic Loss = 111746181.9795
# Episode 86: Total Reward = -585007.0499999966, Avg Actor Loss = -16.4600, Avg Critic Loss = 107003797.5754
# Episode 87: Total Reward = -552571.5699999956, Avg Actor Loss = -18.4963, Avg Critic Loss = 111707271.0880
# Episode 88: Total Reward = -357958.68999999855, Avg Actor Loss = -65.8612, Avg Critic Loss = 173152289.2754
# Episode 89: Total Reward = -450631.4899999965, Avg Actor Loss = -22.4391, Avg Critic Loss = 136439605.0826
# Episode 90: Total Reward = -552571.5699999956, Avg Actor Loss = -20.7096, Avg Critic Loss = 112051084.3882
# Episode 91: Total Reward = -515502.44999999506, Avg Actor Loss = -20.8012, Avg Critic Loss = 120408715.7774
# Episode 92: Total Reward = -422829.6499999971, Avg Actor Loss = 725.7061, Avg Critic Loss = 147578892.2033
# Episode 93: Total Reward = -603541.6099999971, Avg Actor Loss = -48.2312, Avg Critic Loss = 102813285.4319
# Episode 94: Total Reward = -427463.289999997, Avg Actor Loss = -35.2160, Avg Critic Loss = 145710233.1291
# Episode 95: Total Reward = -381126.88999999803, Avg Actor Loss = -90.1146, Avg Critic Loss = 166203036.7372
# Episode 96: Total Reward = -450631.4899999965, Avg Actor Loss = -15.4194, Avg Critic Loss = 137715389.3909
# Episode 97: Total Reward = -441364.2099999967, Avg Actor Loss = -33.3828, Avg Critic Loss = 140331208.1996
# Episode 98: Total Reward = -534037.0099999951, Avg Actor Loss = -50.6813, Avg Critic Loss = 116824592.6141
# Episode 99: Total Reward = -469166.0499999961, Avg Actor Loss = -16.8950, Avg Critic Loss = 132673112.2925
# Episode 100: Total Reward = -413562.3699999973, Avg Actor Loss = -25.4246, Avg Critic Loss = 149748987.6935
# Episode 101: Total Reward = -441364.2099999967, Avg Actor Loss = -31.8871, Avg Critic Loss = 139750497.0363
# Episode 102: Total Reward = -580373.4099999964, Avg Actor Loss = -23.1576, Avg Critic Loss = 105684848.8895
# Episode 103: Total Reward = -483066.9699999958, Avg Actor Loss = -86.2613, Avg Critic Loss = 127669016.6214
# Episode 104: Total Reward = -594274.3299999968, Avg Actor Loss = 7.6067, Avg Critic Loss = 103779042.3015
# Episode 105: Total Reward = -677679.8499999992, Avg Actor Loss = 12735.6883, Avg Critic Loss = 90890550.9263
# Episode 106: Total Reward = -571106.1299999962, Avg Actor Loss = -24.5016, Avg Critic Loss = 108520605.0022
# Episode 107: Total Reward = -487700.6099999957, Avg Actor Loss = -30.6077, Avg Critic Loss = 127014014.3593
# Episode 108: Total Reward = -469166.0499999961, Avg Actor Loss = -21.8106, Avg Critic Loss = 132556497.0893
# Episode 109: Total Reward = -487700.6099999957, Avg Actor Loss = -11.3203, Avg Critic Loss = 126669210.4444
# Episode 110: Total Reward = -598907.969999997, Avg Actor Loss = -23.5028, Avg Critic Loss = 103599405.8000
# Episode 111: Total Reward = -469166.0499999961, Avg Actor Loss = -35.6169, Avg Critic Loss = 132048345.2755
# Episode 112: Total Reward = -524769.7299999949, Avg Actor Loss = -24.4747, Avg Critic Loss = 117536695.9707
# Episode 113: Total Reward = -524769.7299999949, Avg Actor Loss = -34.8027, Avg Critic Loss = 117307732.6467
# Episode 114: Total Reward = -571106.1299999962, Avg Actor Loss = -11.3690, Avg Critic Loss = 109265338.9210
# Episode 115: Total Reward = -404295.0899999975, Avg Actor Loss = -24.5325, Avg Critic Loss = 152174838.5893
# Episode 116: Total Reward = -464532.4099999962, Avg Actor Loss = -41.5521, Avg Critic Loss = 132713038.1484
# Episode 117: Total Reward = -383443.709999998, Avg Actor Loss = 12948.7134, Avg Critic Loss = 161755891.9480
# Episode 118: Total Reward = -418196.0099999972, Avg Actor Loss = -25.3847, Avg Critic Loss = 149086791.3875
# Episode 119: Total Reward = -501601.5299999954, Avg Actor Loss = 13731.7723, Avg Critic Loss = 122846680.1728
# Episode 120: Total Reward = -473799.689999996, Avg Actor Loss = -27.3010, Avg Critic Loss = 131892798.1112
# Episode 121: Total Reward = -392710.9899999978, Avg Actor Loss = 6436.0247, Avg Critic Loss = 160475618.5534
# Episode 122: Total Reward = -385760.52999999793, Avg Actor Loss = -22.6586, Avg Critic Loss = 161948881.0482
# Episode 123: Total Reward = -436730.5699999968, Avg Actor Loss = -24.4175, Avg Critic Loss = 143322640.8897
# Episode 124: Total Reward = -408928.7299999974, Avg Actor Loss = -32.0341, Avg Critic Loss = 152226213.6838
# Episode 125: Total Reward = -395027.8099999977, Avg Actor Loss = -42.0398, Avg Critic Loss = 156845089.5446
# Episode 126: Total Reward = -589640.6899999967, Avg Actor Loss = 45.2053, Avg Critic Loss = 104652407.3190
# Episode 127: Total Reward = -496967.8899999955, Avg Actor Loss = -31.8412, Avg Critic Loss = 124907009.4063
# Episode 128: Total Reward = -547937.9299999955, Avg Actor Loss = -29.5888, Avg Critic Loss = 111570668.4161
# Episode 129: Total Reward = -575739.7699999963, Avg Actor Loss = -26.1772, Avg Critic Loss = 107972798.1707
# Episode 130: Total Reward = -673046.209999999, Avg Actor Loss = -16.1750, Avg Critic Loss = 91514768.6336
# Episode 131: Total Reward = -524769.7299999949, Avg Actor Loss = -22.1689, Avg Critic Loss = 118182010.1050
# Episode 132: Total Reward = -571106.1299999962, Avg Actor Loss = 10157.4841, Avg Critic Loss = 108051582.3335
# Episode 133: Total Reward = -395027.8099999977, Avg Actor Loss = -45.2440, Avg Critic Loss = 156571885.4158
# Episode 134: Total Reward = -448314.66999999655, Avg Actor Loss = 34395.3963, Avg Critic Loss = 138543141.7930
# Episode 135: Total Reward = -547937.9299999955, Avg Actor Loss = -60.1535, Avg Critic Loss = 111655653.4190
# Episode 136: Total Reward = -501601.5299999954, Avg Actor Loss = -35.7898, Avg Critic Loss = 122659224.3369
# Episode 137: Total Reward = -473799.689999996, Avg Actor Loss = -48.5723, Avg Critic Loss = 133210848.4846
# Episode 138: Total Reward = -464532.4099999962, Avg Actor Loss = -27.0273, Avg Critic Loss = 133206245.0864
# Episode 139: Total Reward = -390394.16999999783, Avg Actor Loss = -37.3213, Avg Critic Loss = 159716826.4808
# Episode 140: Total Reward = -376493.24999999814, Avg Actor Loss = -53.5937, Avg Critic Loss = 164369981.0401
# Episode 141: Total Reward = -566472.489999996, Avg Actor Loss = -38.6873, Avg Critic Loss = 110012729.2449
# Episode 142: Total Reward = -414720.7799999973, Avg Actor Loss = 7414.6045, Avg Critic Loss = 148910632.3582
# Episode 143: Total Reward = -492334.2499999956, Avg Actor Loss = -42.6236, Avg Critic Loss = 126703109.9955
# Episode 144: Total Reward = -473799.689999996, Avg Actor Loss = -84.4188, Avg Critic Loss = 132409292.6134
# Episode 145: Total Reward = -395027.8099999977, Avg Actor Loss = -50.6722, Avg Critic Loss = 157103251.7284
# Episode 146: Total Reward = -436730.5699999968, Avg Actor Loss = -30.9488, Avg Critic Loss = 143001978.6032
# Episode 147: Total Reward = -371859.60999999824, Avg Actor Loss = -31.5437, Avg Critic Loss = 165921986.6057
# Episode 148: Total Reward = -432096.9299999969, Avg Actor Loss = -28.0803, Avg Critic Loss = 143157955.3159
# Episode 149: Total Reward = -469166.0499999961, Avg Actor Loss = -31.5670, Avg Critic Loss = 132287713.4101
# Episode 150: Total Reward = -492334.2499999956, Avg Actor Loss = -24.6233, Avg Critic Loss = 126603863.3687
# Episode 151: Total Reward = -575739.7699999963, Avg Actor Loss = -43.7148, Avg Critic Loss = 106856285.7657
# Episode 152: Total Reward = -419354.4199999972, Avg Actor Loss = 819.6247, Avg Critic Loss = 149315535.7459
# Episode 153: Total Reward = -496967.8899999955, Avg Actor Loss = -27.2634, Avg Critic Loss = 123750153.8816
# Episode 154: Total Reward = -419354.4199999972, Avg Actor Loss = 17253.7127, Avg Critic Loss = 147272944.4495
# Episode 155: Total Reward = -427463.289999997, Avg Actor Loss = -19.8743, Avg Critic Loss = 143982521.5951
# Episode 156: Total Reward = -455265.1299999964, Avg Actor Loss = -27.6062, Avg Critic Loss = 135871432.4786
# Episode 157: Total Reward = -422829.6499999971, Avg Actor Loss = -30.8155, Avg Critic Loss = 146913386.6646
# Episode 158: Total Reward = -529403.369999995, Avg Actor Loss = 0.4113, Avg Critic Loss = 117408372.8619
# Episode 159: Total Reward = -561838.8499999959, Avg Actor Loss = 357.8907, Avg Critic Loss = 109437357.5159
# Episode 160: Total Reward = -459898.7699999963, Avg Actor Loss = -27.6393, Avg Critic Loss = 134569663.3881
# Episode 161: Total Reward = -367225.96999999834, Avg Actor Loss = -38.8018, Avg Critic Loss = 168573958.8186
# Episode 162: Total Reward = -506235.16999999527, Avg Actor Loss = -25.5987, Avg Critic Loss = 122489669.0811
# Episode 163: Total Reward = -459898.7699999963, Avg Actor Loss = -23.0549, Avg Critic Loss = 133783799.2846
# Episode 164: Total Reward = -585007.0499999966, Avg Actor Loss = -5.0539, Avg Critic Loss = 104810167.4876
# Episode 165: Total Reward = -543304.2899999954, Avg Actor Loss = -29.5026, Avg Critic Loss = 114140139.9965
# Episode 166: Total Reward = -432096.9299999969, Avg Actor Loss = -32.3988, Avg Critic Loss = 145329263.4505
# Episode 167: Total Reward = -426304.87999999704, Avg Actor Loss = 863.9437, Avg Critic Loss = 145520716.7845
# Episode 168: Total Reward = -427463.289999997, Avg Actor Loss = -29.4642, Avg Critic Loss = 146305963.7270
# Episode 169: Total Reward = -450631.4899999965, Avg Actor Loss = -45.2325, Avg Critic Loss = 135316283.4966
# Episode 170: Total Reward = -450631.4899999965, Avg Actor Loss = 16377.5754, Avg Critic Loss = 138753501.1846
# Episode 171: Total Reward = -432096.9299999969, Avg Actor Loss = 15853.8887, Avg Critic Loss = 144295342.8904
# Episode 172: Total Reward = -339424.12999999896, Avg Actor Loss = -68.7397, Avg Critic Loss = 182513852.7884
# Episode 173: Total Reward = -381126.88999999803, Avg Actor Loss = -36.9770, Avg Critic Loss = 162468816.4778
# Episode 174: Total Reward = -496967.8899999955, Avg Actor Loss = -40.2818, Avg Critic Loss = 124069472.9571
# Episode 175: Total Reward = -376493.24999999814, Avg Actor Loss = -21.0114, Avg Critic Loss = 165412240.4614
# Episode 176: Total Reward = -506235.16999999527, Avg Actor Loss = -27.7627, Avg Critic Loss = 122483237.2524
# Episode 177: Total Reward = -455265.1299999964, Avg Actor Loss = -71.1037, Avg Critic Loss = 135565877.0035
# Episode 178: Total Reward = -376493.24999999814, Avg Actor Loss = -117.8145, Avg Critic Loss = 165738474.2332
# Episode 179: Total Reward = -344057.76999999885, Avg Actor Loss = -148.6951, Avg Critic Loss = 180617458.4126
# Episode 180: Total Reward = -362592.32999999844, Avg Actor Loss = -27.7542, Avg Critic Loss = 172255159.6012
# Episode 181: Total Reward = -364909.1499999984, Avg Actor Loss = 727.4240, Avg Critic Loss = 167904339.1574
# Episode 182: Total Reward = -473799.689999996, Avg Actor Loss = -30.3915, Avg Critic Loss = 130318517.8881
# Episode 183: Total Reward = -413562.3699999973, Avg Actor Loss = -47.4427, Avg Critic Loss = 147826314.9689
# Episode 184: Total Reward = -390394.16999999783, Avg Actor Loss = -44.7938, Avg Critic Loss = 159795250.2910
# Episode 185: Total Reward = -473799.689999996, Avg Actor Loss = 26.9963, Avg Critic Loss = 130172699.8230
# Episode 186: Total Reward = -473799.689999996, Avg Actor Loss = 36.3228, Avg Critic Loss = 130946778.5110
# Episode 187: Total Reward = -385760.52999999793, Avg Actor Loss = -62.7907, Avg Critic Loss = 162217930.9750
# Episode 188: Total Reward = -459898.7699999963, Avg Actor Loss = -43.9441, Avg Critic Loss = 133320147.6940
# Episode 189: Total Reward = -445997.8499999966, Avg Actor Loss = -37.1651, Avg Critic Loss = 137785662.8754
# Episode 190: Total Reward = -376493.24999999814, Avg Actor Loss = -42.8072, Avg Critic Loss = 165877748.4549
# Episode 191: Total Reward = -316255.92999999947, Avg Actor Loss = -36.8367, Avg Critic Loss = 196149122.3302
# Episode 192: Total Reward = -413562.3699999973, Avg Actor Loss = -40.7793, Avg Critic Loss = 148837862.4784
# Episode 193: Total Reward = -496967.8899999955, Avg Actor Loss = -19.7806, Avg Critic Loss = 124356323.3048
# Episode 194: Total Reward = -432096.9299999969, Avg Actor Loss = -29.9613, Avg Critic Loss = 144678883.7225
# Episode 195: Total Reward = -469166.0499999961, Avg Actor Loss = -62.5257, Avg Critic Loss = 133411842.3373
# Episode 196: Total Reward = -459898.7699999963, Avg Actor Loss = -38.5136, Avg Critic Loss = 134570959.6632
# Episode 197: Total Reward = -436730.5699999968, Avg Actor Loss = -36.6503, Avg Critic Loss = 141873679.9671
# Episode 198: Total Reward = -608175.2499999972, Avg Actor Loss = -4.0514, Avg Critic Loss = 101686539.7759
# Episode 199: Total Reward = -399661.4499999976, Avg Actor Loss = -45.0874, Avg Critic Loss = 154231466.4702
# Episode 200: Total Reward = -390394.16999999783, Avg Actor Loss = -78.5312, Avg Critic Loss = 159403075.2119
# Episode 201: Total Reward = -399661.4499999976, Avg Actor Loss = -35.3752, Avg Critic Loss = 155707787.1007
# Episode 202: Total Reward = -353325.04999999865, Avg Actor Loss = -33.1570, Avg Critic Loss = 174847665.5277
# Episode 203: Total Reward = -524769.7299999949, Avg Actor Loss = -26.7454, Avg Critic Loss = 117807031.6582
# Episode 204: Total Reward = -410087.1399999974, Avg Actor Loss = 8674.9363, Avg Critic Loss = 150476673.5439
# Episode 205: Total Reward = -381126.88999999803, Avg Actor Loss = -15.8532, Avg Critic Loss = 163148859.0470
# Episode 206: Total Reward = -381126.88999999803, Avg Actor Loss = -36.3682, Avg Critic Loss = 161140679.2548
# Episode 207: Total Reward = -404295.0899999975, Avg Actor Loss = -17.7548, Avg Critic Loss = 156155169.9732
# Episode 208: Total Reward = -473799.689999996, Avg Actor Loss = -19.8538, Avg Critic Loss = 131074081.9344
# Episode 209: Total Reward = -405453.4999999975, Avg Actor Loss = 1013.8928, Avg Critic Loss = 150157635.0441
# Episode 210: Total Reward = -325523.20999999926, Avg Actor Loss = 18861.5176, Avg Critic Loss = 189111842.0163
# Episode 211: Total Reward = -443681.02999999665, Avg Actor Loss = 13.3539, Avg Critic Loss = 138054737.9879
# Episode 212: Total Reward = -547937.9299999955, Avg Actor Loss = -1.1378, Avg Critic Loss = 112379417.6865
# Episode 213: Total Reward = -483066.9699999958, Avg Actor Loss = -15.0053, Avg Critic Loss = 127664007.5215
# Episode 214: Total Reward = -302355.0099999998, Avg Actor Loss = -27.0338, Avg Critic Loss = 206146257.8516
# Episode 215: Total Reward = -334790.48999999906, Avg Actor Loss = -36.7906, Avg Critic Loss = 184605811.6080
# Episode 216: Total Reward = -413562.3699999973, Avg Actor Loss = -18.0687, Avg Critic Loss = 149523068.0463
# Episode 217: Total Reward = -538670.6499999953, Avg Actor Loss = -21.4027, Avg Critic Loss = 114937966.4048
# Episode 218: Total Reward = -436730.5699999968, Avg Actor Loss = -34.1102, Avg Critic Loss = 140681249.0983
# Episode 219: Total Reward = -534037.0099999951, Avg Actor Loss = -27.6039, Avg Critic Loss = 116261345.9731
# Episode 220: Total Reward = -376493.24999999814, Avg Actor Loss = -36.3823, Avg Critic Loss = 164917450.9770
# Episode 221: Total Reward = -418196.0099999972, Avg Actor Loss = 8430.5975, Avg Critic Loss = 149090454.0068
# Episode 222: Total Reward = -288454.0900000001, Avg Actor Loss = -22.3234, Avg Critic Loss = 213569194.2524
# Episode 223: Total Reward = -362592.32999999844, Avg Actor Loss = 21355.7708, Avg Critic Loss = 170923018.4235
# Episode 224: Total Reward = -367225.96999999834, Avg Actor Loss = 16522.4293, Avg Critic Loss = 167534582.9464
# Episode 225: Total Reward = -510868.80999999517, Avg Actor Loss = -43.9364, Avg Critic Loss = 120175846.5316
# Episode 226: Total Reward = -404295.0899999975, Avg Actor Loss = 4319.2692, Avg Critic Loss = 151922265.4252
# Episode 227: Total Reward = -348691.40999999875, Avg Actor Loss = -43.9842, Avg Critic Loss = 177024316.2505
# Episode 228: Total Reward = -496967.8899999955, Avg Actor Loss = -18.3576, Avg Critic Loss = 124472133.4639
# Episode 229: Total Reward = -395027.8099999977, Avg Actor Loss = -52.2123, Avg Critic Loss = 158512175.2883
# Episode 230: Total Reward = -357958.68999999855, Avg Actor Loss = -39.9669, Avg Critic Loss = 172972422.4557
# Episode 231: Total Reward = -413562.3699999973, Avg Actor Loss = -18.7805, Avg Critic Loss = 150567998.0753
# Episode 232: Total Reward = -339424.12999999896, Avg Actor Loss = -22.1389, Avg Critic Loss = 181599180.3257
# Episode 233: Total Reward = -515502.44999999506, Avg Actor Loss = -29.6328, Avg Critic Loss = 120901996.8389
# Episode 234: Total Reward = -450631.4899999965, Avg Actor Loss = -28.0442, Avg Critic Loss = 136453350.2426
# Episode 235: Total Reward = -459898.7699999963, Avg Actor Loss = -17.6132, Avg Critic Loss = 134947497.8604
# Episode 236: Total Reward = -288454.0900000001, Avg Actor Loss = -41.6097, Avg Critic Loss = 213545509.6067
# Episode 237: Total Reward = -473799.689999996, Avg Actor Loss = -37.8432, Avg Critic Loss = 129948060.2870
# Episode 238: Total Reward = -223583.13000000056, Avg Actor Loss = -62.7993, Avg Critic Loss = 283721540.9178
# Episode 239: Total Reward = -260652.25000000067, Avg Actor Loss = -44.3271, Avg Critic Loss = 237258488.6993
# Episode 240: Total Reward = -404295.0899999975, Avg Actor Loss = -13.4706, Avg Critic Loss = 151010391.1147
# Episode 241: Total Reward = -737917.1700000009, Avg Actor Loss = -48.7688, Avg Critic Loss = 84064364.1270
# Episode 242: Total Reward = -320889.56999999937, Avg Actor Loss = -45.3103, Avg Critic Loss = 191932801.3979
# Episode 243: Total Reward = -344057.76999999885, Avg Actor Loss = -50.5823, Avg Critic Loss = 180716884.3788
# Episode 244: Total Reward = -385760.52999999793, Avg Actor Loss = -20.8736, Avg Critic Loss = 160471980.8460
# Episode 245: Total Reward = -385760.52999999793, Avg Actor Loss = -25.2521, Avg Critic Loss = 160616987.3968
# Episode 246: Total Reward = -334790.48999999906, Avg Actor Loss = -22.5631, Avg Critic Loss = 186064265.6329
# Episode 247: Total Reward = -408928.7299999974, Avg Actor Loss = -20.7347, Avg Critic Loss = 150280097.3592
# Episode 248: Total Reward = -320889.56999999937, Avg Actor Loss = -37.2744, Avg Critic Loss = 192665907.7099
# Episode 249: Total Reward = -404295.0899999975, Avg Actor Loss = -44.7605, Avg Critic Loss = 152463759.2144
# Episode 250: Total Reward = -575739.7699999963, Avg Actor Loss = -14.5693, Avg Critic Loss = 107069061.0761
# Episode 251: Total Reward = -357958.68999999855, Avg Actor Loss = -25.5090, Avg Critic Loss = 173497117.5183
# Episode 252: Total Reward = -362592.32999999844, Avg Actor Loss = -28.1400, Avg Critic Loss = 169249159.4561
# Episode 253: Total Reward = -320889.56999999937, Avg Actor Loss = -42.5403, Avg Critic Loss = 192816163.5512
# Episode 254: Total Reward = -413562.3699999973, Avg Actor Loss = -31.6920, Avg Critic Loss = 150100077.0064
# Episode 255: Total Reward = -445997.8499999966, Avg Actor Loss = -50.3327, Avg Critic Loss = 137956266.5292
# Episode 256: Total Reward = -353325.04999999865, Avg Actor Loss = -22.6885, Avg Critic Loss = 174787829.9918
# Episode 257: Total Reward = -334790.48999999906, Avg Actor Loss = -39.6164, Avg Critic Loss = 186092842.8495
# Episode 258: Total Reward = -344057.76999999885, Avg Actor Loss = -59.8026, Avg Critic Loss = 181342499.4578
# Episode 259: Total Reward = -422829.6499999971, Avg Actor Loss = -86.6741, Avg Critic Loss = 145304264.9513
# Episode 260: Total Reward = -280345.22000000026, Avg Actor Loss = 10274.7128, Avg Critic Loss = 218172762.6733
# Episode 261: Total Reward = -330156.84999999916, Avg Actor Loss = -64.1628, Avg Critic Loss = 188380281.5477
# Episode 262: Total Reward = -436730.5699999968, Avg Actor Loss = -11.4614, Avg Critic Loss = 140287238.4446
# Episode 263: Total Reward = -547937.9299999955, Avg Actor Loss = -16.7160, Avg Critic Loss = 113512905.4675
# Episode 264: Total Reward = -353325.04999999865, Avg Actor Loss = -53.2988, Avg Critic Loss = 173545501.2686
# Episode 265: Total Reward = -376493.24999999814, Avg Actor Loss = -15.5679, Avg Critic Loss = 163235804.0454
# Episode 266: Total Reward = -357958.68999999855, Avg Actor Loss = -40.1924, Avg Critic Loss = 173077216.6923
# Episode 267: Total Reward = -640610.7299999981, Avg Actor Loss = -34.5211, Avg Critic Loss = 95940526.0758
# Episode 268: Total Reward = -598907.969999997, Avg Actor Loss = -17.4246, Avg Critic Loss = 102856606.2338
# Episode 269: Total Reward = -418196.0099999972, Avg Actor Loss = -31.2599, Avg Critic Loss = 147290976.9469
# Episode 270: Total Reward = -385760.52999999793, Avg Actor Loss = -17.4727, Avg Critic Loss = 160388521.0947
# Episode 271: Total Reward = -328998.4399999992, Avg Actor Loss = 19271.7472, Avg Critic Loss = 189794178.7879
# Episode 272: Total Reward = -344057.76999999885, Avg Actor Loss = -43.9453, Avg Critic Loss = 179262335.0656
# Episode 273: Total Reward = -353325.04999999865, Avg Actor Loss = -32.3700, Avg Critic Loss = 176127878.3693
# Episode 274: Total Reward = -353325.04999999865, Avg Actor Loss = -27.4864, Avg Critic Loss = 175207650.3945
# Episode 275: Total Reward = -450631.4899999965, Avg Actor Loss = 46.0635, Avg Critic Loss = 137261720.4518
# Episode 276: Total Reward = -506235.16999999527, Avg Actor Loss = -120.0475, Avg Critic Loss = 121224706.6644
# Episode 277: Total Reward = -279186.8100000003, Avg Actor Loss = -36.0952, Avg Critic Loss = 221974643.3814
# Episode 278: Total Reward = -408928.7299999974, Avg Actor Loss = -47.5349, Avg Critic Loss = 150335266.0295
# Episode 279: Total Reward = -320889.56999999937, Avg Actor Loss = -7.3618, Avg Critic Loss = 192163445.2930
# Episode 280: Total Reward = -325523.20999999926, Avg Actor Loss = -39.5508, Avg Critic Loss = 190623465.8454
# Episode 281: Total Reward = -407770.31999999745, Avg Actor Loss = 15797.1165, Avg Critic Loss = 151014435.1598
# Episode 282: Total Reward = -348691.40999999875, Avg Actor Loss = -13.7980, Avg Critic Loss = 176840210.5046
# Episode 283: Total Reward = -395027.8099999977, Avg Actor Loss = -27.9633, Avg Critic Loss = 157210316.7564
# Episode 284: Total Reward = -320889.56999999937, Avg Actor Loss = -54.2678, Avg Critic Loss = 194303939.0464
# Episode 285: Total Reward = -334790.48999999906, Avg Actor Loss = -45.8913, Avg Critic Loss = 185103431.2253
# Episode 286: Total Reward = -399661.4499999976, Avg Actor Loss = 62.3152, Avg Critic Loss = 153464213.2495
# Episode 287: Total Reward = -371859.60999999824, Avg Actor Loss = -28.5079, Avg Critic Loss = 166300642.2136
# Episode 288: Total Reward = -381126.88999999803, Avg Actor Loss = -27.6069, Avg Critic Loss = 163127041.3553
# Episode 289: Total Reward = -399661.4499999976, Avg Actor Loss = -19.0520, Avg Critic Loss = 155306076.6017
# Episode 290: Total Reward = -334790.48999999906, Avg Actor Loss = -13.7964, Avg Critic Loss = 184947845.6603
# Episode 291: Total Reward = -330156.84999999916, Avg Actor Loss = -55.5624, Avg Critic Loss = 186750884.6943
# Episode 292: Total Reward = -269919.5300000005, Avg Actor Loss = -54.9943, Avg Critic Loss = 234594861.0839
# Episode 293: Total Reward = -316255.92999999947, Avg Actor Loss = 275.8363, Avg Critic Loss = 194783351.3195
# Episode 294: Total Reward = -325523.20999999926, Avg Actor Loss = -21.8989, Avg Critic Loss = 189749592.8438
# Episode 295: Total Reward = -330156.84999999916, Avg Actor Loss = -44.4841, Avg Critic Loss = 188631687.7378
# Episode 296: Total Reward = -288454.0900000001, Avg Actor Loss = -54.1971, Avg Critic Loss = 213167852.8788
# Episode 297: Total Reward = -344057.76999999885, Avg Actor Loss = -20.8570, Avg Critic Loss = 179731173.7507
# Episode 298: Total Reward = -288454.0900000001, Avg Actor Loss = -61.7988, Avg Critic Loss = 215560375.5800
# Episode 299: Total Reward = -390394.16999999783, Avg Actor Loss = -29.1313, Avg Critic Loss = 158098276.1005
# Episode 300: Total Reward = -334790.48999999906, Avg Actor Loss = -30.9279, Avg Critic Loss = 187250591.1442
# Episode 301: Total Reward = -617442.5299999975, Avg Actor Loss = -26.5444, Avg Critic Loss = 100303791.8246
# Episode 302: Total Reward = -326681.61999999924, Avg Actor Loss = 8283.3365, Avg Critic Loss = 188571527.6665
# Episode 303: Total Reward = -325523.20999999926, Avg Actor Loss = -14.9829, Avg Critic Loss = 189384277.5217
# Episode 304: Total Reward = -367225.96999999834, Avg Actor Loss = 0.6381, Avg Critic Loss = 167734407.4343
# Episode 305: Total Reward = -381126.88999999803, Avg Actor Loss = -38.2482, Avg Critic Loss = 161489329.5336
# Episode 306: Total Reward = -390394.16999999783, Avg Actor Loss = -6.9385, Avg Critic Loss = 157655156.6831
# Episode 307: Total Reward = -603541.6099999971, Avg Actor Loss = 14.3152, Avg Critic Loss = 102094267.4287
# Episode 308: Total Reward = -371859.60999999824, Avg Actor Loss = -34.2193, Avg Critic Loss = 165264873.6393
# Episode 309: Total Reward = -478433.3299999959, Avg Actor Loss = -33.8356, Avg Critic Loss = 128526485.9757
# Episode 310: Total Reward = -316255.92999999947, Avg Actor Loss = -14.9961, Avg Critic Loss = 195078453.9936
# Episode 311: Total Reward = -381126.88999999803, Avg Actor Loss = -29.9394, Avg Critic Loss = 162067092.5303
# Episode 312: Total Reward = -399661.4499999976, Avg Actor Loss = -35.3521, Avg Critic Loss = 155384597.7378
# Episode 313: Total Reward = -427463.289999997, Avg Actor Loss = -19.7528, Avg Critic Loss = 144404431.0614
# Episode 314: Total Reward = -381126.88999999803, Avg Actor Loss = -37.9823, Avg Critic Loss = 162903310.2919
# Episode 315: Total Reward = -575739.7699999963, Avg Actor Loss = -21.0559, Avg Critic Loss = 106932716.5931
# Episode 316: Total Reward = -297721.3699999999, Avg Actor Loss = 39042.1806, Avg Critic Loss = 207262821.5966
# Episode 317: Total Reward = -399661.4499999976, Avg Actor Loss = 11.6338, Avg Critic Loss = 154986338.0135
# Episode 318: Total Reward = -529403.369999995, Avg Actor Loss = -16.3108, Avg Critic Loss = 116249833.7339
# Episode 319: Total Reward = -450631.4899999965, Avg Actor Loss = -8.3429, Avg Critic Loss = 137223168.0107
# Episode 320: Total Reward = -381126.88999999803, Avg Actor Loss = -17.0456, Avg Critic Loss = 163936069.1294
# Episode 321: Total Reward = -320889.56999999937, Avg Actor Loss = 26558.6150, Avg Critic Loss = 192335462.0916
# Episode 322: Total Reward = -348691.40999999875, Avg Actor Loss = 5.7033, Avg Critic Loss = 177605666.2172
# Episode 323: Total Reward = -404295.0899999975, Avg Actor Loss = -33.0734, Avg Critic Loss = 153932367.2051
# Episode 324: Total Reward = -473799.689999996, Avg Actor Loss = -45.6184, Avg Critic Loss = 130746536.0119
# Episode 325: Total Reward = -294246.13999999996, Avg Actor Loss = 16705.0455, Avg Critic Loss = 210355532.6839
# Episode 326: Total Reward = -390394.16999999783, Avg Actor Loss = -20.1316, Avg Critic Loss = 159646942.8871
# Episode 327: Total Reward = -320889.56999999937, Avg Actor Loss = -20.1632, Avg Critic Loss = 195205614.6363
# Episode 328: Total Reward = -413562.3699999973, Avg Actor Loss = 91.8594, Avg Critic Loss = 149209380.3044
# Episode 329: Total Reward = -339424.12999999896, Avg Actor Loss = 69.5743, Avg Critic Loss = 183530317.1172
# Episode 330: Total Reward = -390394.16999999783, Avg Actor Loss = -31.9384, Avg Critic Loss = 159353207.7677
# Episode 331: Total Reward = -445997.8499999966, Avg Actor Loss = nan, Avg Critic Loss = 137586919.2760
# Episode 332: Total Reward = -649878.0099999984, Avg Actor Loss = nan, Avg Critic Loss = 95633270.7810
# Episode 333: Total Reward = -645244.3699999982, Avg Actor Loss = nan, Avg Critic Loss = 96209278.4466
# Episode 334: Total Reward = -673046.209999999, Avg Actor Loss = nan, Avg Critic Loss = 92055347.1707
# Episode 335: Total Reward = -654511.6499999985, Avg Actor Loss = nan, Avg Critic Loss = 94869179.8094
# Episode 336: Total Reward = -515502.44999999506, Avg Actor Loss = nan, Avg Critic Loss = 119810068.2805
# Episode 337: Total Reward = -561838.8499999959, Avg Actor Loss = nan, Avg Critic Loss = 109204951.4771
# Episode 338: Total Reward = -756451.7300000014, Avg Actor Loss = nan, Avg Critic Loss = 81655164.4525
# Episode 339: Total Reward = -529403.369999995, Avg Actor Loss = nan, Avg Critic Loss = 116658489.7039
# Episode 340: Total Reward = -802788.1300000027, Avg Actor Loss = nan, Avg Critic Loss = 77155899.0707
# Episode 341: Total Reward = -765719.0100000016, Avg Actor Loss = nan, Avg Critic Loss = 80416963.2642
# Episode 342: Total Reward = -645244.3699999982, Avg Actor Loss = nan, Avg Critic Loss = 95872353.3992
# Episode 343: Total Reward = -580373.4099999964, Avg Actor Loss = nan, Avg Critic Loss = 106130852.1560
# Episode 344: Total Reward = -585007.0499999966, Avg Actor Loss = nan, Avg Critic Loss = 105973505.1739
# Episode 345: Total Reward = -691580.7699999996, Avg Actor Loss = nan, Avg Critic Loss = 90163982.0078
# Episode 346: Total Reward = -645244.3699999982, Avg Actor Loss = nan, Avg Critic Loss = 96044425.0775
# Episode 347: Total Reward = -566472.489999996, Avg Actor Loss = nan, Avg Critic Loss = 108559960.0038
# Episode 348: Total Reward = -742550.810000001, Avg Actor Loss = nan, Avg Critic Loss = 82715578.7334
# Episode 349: Total Reward = -663778.9299999988, Avg Actor Loss = nan, Avg Critic Loss = 92690011.8128
# Episode 350: Total Reward = -571106.1299999962, Avg Actor Loss = nan, Avg Critic Loss = 108113046.9350
# Episode 351: Total Reward = -598907.969999997, Avg Actor Loss = nan, Avg Critic Loss = 103388473.8085
# Episode 352: Total Reward = -673046.209999999, Avg Actor Loss = nan, Avg Critic Loss = 91385230.6311

# %%
# Reset the environment and get the initial observation
env = gym.make("ALE/Tetris-v5", render_mode="human")
observation, _ = env.reset()
print("Observation structure:", observation.shape)  # Add this line to inspect the observation
# Out:
# Observation structure: (210, 160, 3)
